# %%
def data_read(file_name):
    open_file =open(file_name,encoding="utf8")
    from csv import reader
    read_file = reader(open_file)
    return list(read_file)
apple_data = data_read('AppleStore.csv')
google_data = data_read('googleplaystore.csv')

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
explore_data(apple_data,0,6)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']

# %%
explore_data(google_data,0,6)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ...

# %%
 del google_data[10473]

# %%
google_data[10473]
# Out:
# ['osmino Wi-Fi: free WiFi',
#  'TOOLS',
#  '4.2',
#  '134203',
#  '4.1M',
#  '10,000,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Tools',
#  'August 7, 2018',
#  '6.06.14',
#  '4.4 and up']

# %%
duplicate_apps =[]
unique_apps = []
for row in google_data :
    if row[0] in unique_apps :
        duplicate_apps.append(row[0])
    else :
        unique_apps.append(row[0])
duplicate_app_count = len(duplicate_apps)        
print(duplicate_app_count)
print(len(unique_apps))
# Out:
# 1181
# 9660

# %%
review_max = {}
for row in google_data[1:] :
    app_name = row[0]
    n_reviews = float(row[3])
    if app_name  in review_max and review_max[app_name] < n_reviews :
        review_max[app_name] = n_reviews
    if app_name not in review_max:
        review_max[app_name] = n_reviews
print(len(review_max))
# Out:
# 9659

# %%
android_clean = []
already_added = []
for row in google_data[1:] :
    name =  row[0]
    n_reviews = float(row[3])
    if n_reviews == review_max[name] and name not in already_added :
        android_clean.append(row)
        already_added.append(name)
len(android_clean)
print(android_clean[0:5])
# Out:
# [['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up'], ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up'], ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up'], ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up'], ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']]

# %%
def str_numb(strng):
    number_of_characters = 0
    for character in strng :
        if ord(character) > 127 :
            number_of_characters+=1
    if number_of_characters > 3 :
        return False
    else :
        return True
        

print(str_numb('Instagram'))     
print(str_numb('爱奇艺PPS -《欢乐颂2》电视剧热播'))  
print(str_numb('Docs To Go™ Free Office Suite')) 
print(str_numb('Instachat 😜'))
# Out:
# True
# False
# True
# True

# %%
apple_eng_apps = []
google_eng_apps = []
for row in apple_data[1:] :
   app_name = row[1]
   if str_numb(app_name) :
        apple_eng_apps.append(row)
print(apple_eng_apps[:5])

for row in android_clean :
   app_name = row[0]
   if str_numb(app_name) :
        google_eng_apps.append(row)
print(google_eng_apps[:5])
# Out:
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1'], ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1'], ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1'], ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1'], ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']]
# ...

# %%
print(len(google_data))
print(len(android_clean))
print(len(google_eng_apps))
print(len(apple_data))
print(len(apple_eng_apps))
# Out:
# 10841
# 9659
# 9614
# 7198
# 6183

# %%
print(apple_data[0].index('price'))
print(google_data[0].index('Price'))
google_eng_apps[1][7]
# Out:
# 4
# 7
# '0'

# %%
def free_app_sep(data,index) :
    temp_data =[]
    for row in data :
        if row[index] in ('0','0.0') :
            temp_data.append(row)
    return temp_data
apple_eng_free_apps = free_app_sep(apple_eng_apps,4)
google_eng_free_apps = free_app_sep(google_eng_apps,7)
print(len(apple_eng_free_apps))
print(len(google_eng_free_apps))
# Out:
# 3222
# 8864

# %%
apple_genre_list =[]
for row in apple_eng_free_apps :
    apple_genre_list.append(row[apple_data[0].index('prime_genre')])        
print(set(apple_genre_list))
# Out:
# {'Productivity', 'Weather', 'Business', 'Lifestyle', 'Medical', 'Finance', 'Health & Fitness', 'Photo & Video', 'Music', 'Navigation', 'Food & Drink', 'News', 'Sports', 'Utilities', 'Catalogs', 'Games', 'Book', 'Education', 'Entertainment', 'Reference', 'Travel', 'Social Networking', 'Shopping'}

# %%
google_category_list =[]
for row in google_eng_free_apps :
    google_category_list.append(row[google_data[0].index('Category')])        
print(set(google_category_list))
# Out:
# {'PHOTOGRAPHY', 'TRAVEL_AND_LOCAL', 'DATING', 'NEWS_AND_MAGAZINES', 'SPORTS', 'SHOPPING', 'PRODUCTIVITY', 'FINANCE', 'ENTERTAINMENT', 'COMICS', 'BEAUTY', 'COMMUNICATION', 'GAME', 'HEALTH_AND_FITNESS', 'MEDICAL', 'LIBRARIES_AND_DEMO', 'EDUCATION', 'FAMILY', 'SOCIAL', 'HOUSE_AND_HOME', 'TOOLS', 'PERSONALIZATION', 'FOOD_AND_DRINK', 'AUTO_AND_VEHICLES', 'BUSINESS', 'EVENTS', 'VIDEO_PLAYERS', 'WEATHER', 'LIFESTYLE', 'BOOKS_AND_REFERENCE', 'MAPS_AND_NAVIGATION', 'ART_AND_DESIGN', 'PARENTING'}

# %%
google_genre_list =[]
for row in google_eng_free_apps :
    google_genre_list.append(row[google_data[0].index('Genres')])        
print(set(google_genre_list))
# Out:
# {'Board', 'Productivity', 'Tools;Education', 'Action', 'Education;Pretend Play', 'Health & Fitness', 'Art & Design;Creativity', 'Entertainment;Action & Adventure', 'Sports', 'Music;Music & Video', 'Communication', 'Adventure', 'Strategy;Education', 'Parenting', 'Parenting;Music & Video', 'Simulation;Action & Adventure', 'Education;Music & Video', 'Casual', 'Communication;Creativity', 'Simulation;Pretend Play', 'Auto & Vehicles', 'Comics;Creativity', 'Puzzle;Brain Games', 'Puzzle;Action & Adventure', 'Lifestyle;Education', 'Personalization', 'Casual;Brain Games', 'Strategy;Action & Adventure', 'Medical', 'Finance', 'Travel & Local;Action & Adventure', 'Educational;Pretend Play', 'Casual;Education', 'Music', 'Racing;Action & Adventure', 'Photography', 'Educational;Education', 'Role Playing;Pretend Play', 'Entertainment;Brain Games', 'Education', 'Board;Brain Games', 'Entertainment', 'Entertainment;Music & Video', 'Racing', 'Books & Reference', 'Card', 'Beauty', 'Casino', 'Casual;Music 
# ...

# %%
print(apple_data[0].index('prime_genre'))
print(google_data[0].index('Category'))
print(google_data[0].index('Genres'))
# Out:
# 11
# 1
# 9

# %%
def freq_table(dataset,indx):
    temp_dict ={}
    for row in dataset :
        val = row[indx]
        if val in temp_dict :
            temp_dict[val] += 1
        else :
            temp_dict[val] = 1
    for key in temp_dict:
        temp_dict[key]=(temp_dict[key]/len(dataset))*100
    return temp_dict

def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(apple_eng_free_apps,11)
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %%
display_table(google_eng_free_apps,1) #google_category_freq
# Out:
# FAMILY : 18.907942238267147
# GAME : 9.724729241877256
# TOOLS : 8.461191335740072
# BUSINESS : 4.591606498194946
# LIFESTYLE : 3.9034296028880866
# PRODUCTIVITY : 3.892148014440433
# FINANCE : 3.7003610108303246
# MEDICAL : 3.531137184115524
# SPORTS : 3.395758122743682
# PERSONALIZATION : 3.3167870036101084
# COMMUNICATION : 3.2378158844765346
# HEALTH_AND_FITNESS : 3.0798736462093865
# PHOTOGRAPHY : 2.944494584837545
# NEWS_AND_MAGAZINES : 2.7978339350180503
# SOCIAL : 2.6624548736462095
# TRAVEL_AND_LOCAL : 2.33528880866426
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.1435018050541514
# DATING : 1.861462093862816
# VIDEO_PLAYERS : 1.7937725631768955
# MAPS_AND_NAVIGATION : 1.3989169675090252
# FOOD_AND_DRINK : 1.2409747292418771
# EDUCATION : 1.1620036101083033
# ENTERTAINMENT : 0.9589350180505415
# LIBRARIES_AND_DEMO : 0.9363718411552346
# AUTO_AND_VEHICLES : 0.9250902527075812
# HOUSE_AND_HOME : 0.8235559566787004
# WEATHER : 0.8009927797833934
# ...

# %%
 display_table(google_eng_free_apps,9) #google_genre_freq
# Out:
# Tools : 8.449909747292418
# Entertainment : 6.069494584837545
# Education : 5.347472924187725
# Business : 4.591606498194946
# Productivity : 3.892148014440433
# Lifestyle : 3.892148014440433
# Finance : 3.7003610108303246
# Medical : 3.531137184115524
# Sports : 3.463447653429603
# Personalization : 3.3167870036101084
# Communication : 3.2378158844765346
# Action : 3.1024368231046933
# Health & Fitness : 3.0798736462093865
# Photography : 2.944494584837545
# News & Magazines : 2.7978339350180503
# Social : 2.6624548736462095
# Travel & Local : 2.3240072202166067
# Shopping : 2.2450361010830324
# Books & Reference : 2.1435018050541514
# Simulation : 2.0419675090252705
# Dating : 1.861462093862816
# Arcade : 1.8501805054151623
# Video Players & Editors : 1.7712093862815883
# Casual : 1.7599277978339352
# Maps & Navigation : 1.3989169675090252
# Food & Drink : 1.2409747292418771
# Puzzle : 1.128158844765343
# Racing : 0.9927797833935018
# Role Playing : 0.9363718411552346
# ...

# %%
apple_genre_freq = freq_table(apple_eng_free_apps,11)
for genre in apple_genre_freq :
    total = 0
    len_genre = 0
    for row in apple_eng_free_apps:
        genre_app =row[11]
        if genre_app == genre :
            total += float(row[5])
            len_genre += 1
    avg_user_rating = total/len_genre
    print(genre,":",avg_user_rating)
# Out:
# Music : 57326.530303030304
# Productivity : 21028.410714285714
# Education : 7003.983050847458
# Weather : 52279.892857142855
# Business : 7491.117647058823
# Lifestyle : 16485.764705882353
# Catalogs : 4004.0
# Finance : 31467.944444444445
# Food & Drink : 33333.92307692308
# Health & Fitness : 23298.015384615384
# Book : 39758.5
# Photo & Video : 28441.54375
# Entertainment : 14029.830708661417
# Reference : 74942.11111111111
# Navigation : 86090.33333333333
# Medical : 612.0
# News : 21248.023255813954
# Travel : 28243.8
# Sports : 23008.898550724636
# Utilities : 18684.456790123455
# Social Networking : 71548.34905660378
# Shopping : 26919.690476190477
# Games : 22788.6696905016

# %%
google_category_freq = freq_table(google_eng_free_apps,1)
for category in google_category_freq :
    total = 0
    len_category = 0
    for row in google_eng_free_apps :
        category_app = row[1]
        if category_app == category :
            installs = row[5]
            n_installs = float(installs.replace('+','').replace(',',''))
            total += n_installs
            len_category += 1
    avg_user_rating = total/len_category
# Out:
# 50000.0
# 10000.0
# 100000.0
# 1000.0
# 100000.0
# 10000.0
# 100000.0
# 5000000.0
# 50000.0
# 10000000.0
# 1000.0
# 100000.0
# 50000.0
# 100000.0
# 50000.0
# 100000.0
# 10000.0
# 50000.0
# 50000.0
# 100000.0
# 100000.0
# 10000.0
# 100000.0
# 10000.0
# 10000.0
# 5000.0
# 500000.0
# 5000000.0
# 100000.0
# 1000000.0
# 10000.0
# 1000000.0
# 1000.0
# 500000.0
# 1000000.0
# 100000.0
# 1000000.0
# 10000.0
# 1000000.0
# 500000.0
# 500000.0
# 100000.0
# 50000.0
# 500000.0
# 500000.0
# 1000000.0
# 100000.0
# 10000.0
# 1000000.0
# 10000.0
# 10000.0
# 5000.0
# 1000.0
# 10000.0
# 10000.0
# 1000.0
# 5000.0
# 10000.0
# 5000.0
# 5000.0
# 10000.0
# 1000.0
# 5000.0
# 5000.0
# 1000.0
# 10000.0
# 1000.0
# 10000.0
# 10000.0
# 10000.0
# 5000.0
# 10000000.0
# 100.0
# 100.0
# 100.0
# 10.0
# 1000.0
# 1000.0
# 5000.0
# 1000000.0
# 500.0
# 100000.0
# 10000000.0
# 100000.0
# 5000000.0
# 100000.0
# 1000000.0
# 500000.0
# 1000000.0
# 5000000.0
# 1000000.0
# 500000.0
# 500000.0
# 1000000.0
# 10000000.0
# ...
